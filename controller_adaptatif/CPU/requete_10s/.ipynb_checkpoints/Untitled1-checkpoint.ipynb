# %%
ls
# Out:
# all_data_decomposed_controller_10s.csv  invocation_decomposed3.csv
# invocation_decomposed1.csv              Untitled1.ipynb
# invocation_decomposed2.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
  
   
]


#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

# %%
all_data.to_csv("all_data_decomposed_controller_10s.csv", index=False)

# %%
#power_df.to_csv("power_controller_10ms.csv", index=False)
