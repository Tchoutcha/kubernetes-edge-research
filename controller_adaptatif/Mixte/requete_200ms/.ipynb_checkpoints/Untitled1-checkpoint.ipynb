# %%
ls
# Out:
# all_data_decomposed_controller_200ms.csv  invocation_decomposed5.csv
# invocation_decomposed10.csv               invocation_decomposed6.csv
# invocation_decomposed1.csv                invocation_decomposed7.csv
# invocation_decomposed2.csv                invocation_decomposed8.csv
# invocation_decomposed3.csv                invocation_decomposed9.csv
# invocation_decomposed4.csv                Untitled1.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
    "invocation_decomposed4.csv",
    "invocation_decomposed5.csv",
    "invocation_decomposed6.csv",
    "invocation_decomposed7.csv",
    "invocation_decomposed8.csv",
    "invocation_decomposed9.csv",
]


#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

# %%
all_data.to_csv("all_data_decomposed_controller_200ms.csv", index=False)
