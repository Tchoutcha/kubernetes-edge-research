# %%
ls
# Out:
# acti_df_200ms_1core.csv         invocation_results_fixed6.csv
# activator_20260416_153215.log   invocation_results_fixed7.csv
# activator_20260416_154934.log   invocation_results_fixed8.csv
# activator_20260416_160108.log   invocation_results_fixed9.csv
# activator_20260416_161206.log   kourier10.txt
# activator_20260416_162602.log   kourier1.txt
# activator_20260416_163846.log   kourier2.txt
# activator_20260416_164939.log   kourier3.txt
# activator_20260416_170321.log   kourier4.txt
# activator_20260416_171625.log   kourier5.txt
# activator_20260416_173018.log   kourier6.txt
# all_data_200ms_1core.csv        kourier7.txt
# auto_df_200ms_1core.csv         kourier8.txt
# autoscaler_20260416_153215.log  kourier9.txt
# autoscaler_20260416_154934.log  kourier.csv
# autoscaler_20260416_160108.log  kourier_df_200ms_1core.csv
# autoscaler_20260416_161206.log  logs/
# autoscaler_20260416_162602.log  reconcile_times1.csv
# autoscaler_20260416_163846.log  reconcile_times2.csv
# autoscaler_20260416_164939.log  reconcile_times3.csv
# autoscaler_20260416_170321.log  scheduler_20260416_153215.log
# autoscaler_20260416_171625.log  scheduler_20260416_154934.log
# autoscaler_20260416_173018.log  scheduler_20260416_160108.log
# context_handler_times1.csv      scheduler_20260416_161206.log
# context_handler_times2.csv      scheduler_20260416_162602.log
# context_handler_times3.csv      scheduler_20260416_163846.log
# context_handler_times4.csv      scheduler_20260416_164939.log
# context_handler_times5.csv      scheduler_20260416_170321.log
# context_handler_times6.csv      scheduler_20260416_171625.log
# context_handler_times7.csv      scheduler_20260416_173018.log
# invocation_results_fixed10.csv  scheduler_times.csv
# invocation_results_fixed1.csv   script_activator.py
# invocation_results_fixed2.csv   script_autoscale.py
# invocation_results_fixed3.csv   script_kourier.py
# invocation_results_fixed4.csv   script_scheduler.py
# invocation_results_fixed5.csv   Untitled3.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_results_fixed1.csv",
    "invocation_results_fixed2.csv",
    "invocation_results_fixed3.csv",
    "invocation_results_fixed4.csv",
    "invocation_results_fixed5.csv",
    "invocation_results_fixed6.csv",
    "invocation_results_fixed7.csv",
    "invocation_results_fixed8.csv",
    "invocation_results_fixed9.csv",
    "invocation_results_fixed10.csv"
]
kourier = [
   "kourier.csv"
]

pods = [
    "logs/containers_live_20260416_153211.csv",
    "logs/containers_live_20260416_154923.csv",
    "logs/containers_live_20260416_160057.csv",
    "logs/containers_live_20260416_161202.csv",
    "logs/containers_live_20260416_162558.csv",
    "logs/containers_live_20260416_163834.csv",
    "logs/containers_live_20260416_164926.csv",
    "logs/containers_live_20260416_170306.csv",
    "logs/containers_live_20260416_171621.csv",
    "logs/containers_live_20260416_173004.csv"
  
   
]

auto = [
    
    "reconcile_times1.csv",
    "reconcile_times2.csv",
    "reconcile_times3.csv"
   
    
]

acti = [
    "context_handler_times1.csv",
    "context_handler_times2.csv",
    "context_handler_times3.csv",
    "context_handler_times4.csv",
    "context_handler_times5.csv",
    "context_handler_times6.csv",
    "context_handler_times7.csv",
   
    
]
scheduler = pd.read_csv('scheduler_times.csv')

# concaténation

#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

#kourier
kourier_dfs = [pd.read_csv(f) for f in kourier]
kourier_df = pd.concat(kourier_dfs, ignore_index=True)

#pod queue-proxy
dfs = [pd.read_csv(f) for f in pods]  
pod_df = pd.concat(dfs, ignore_index=True)  

#autoscaler
dfs = [pd.read_csv(f) for f in auto]  
auto_df = pd.concat(dfs, ignore_index=True)  

#activator
dfs = [pd.read_csv(f) for f in acti]  
acti_df = pd.concat(dfs, ignore_index=True)  

#acti = pd.read_csv('context_handler_times1.csv')
#auto = pd.read_csv('reconcile_times1.csv')
#df_percentil = pd.read_csv('latency_percentiles.csv')

# %%
#conversion en ms

all_data['execution_time_sec'] = all_data['execution_time_sec'] * 1000


pod_df["createdAt"] = pd.to_datetime(pod_df["createdAt"], errors="coerce", utc=True)
pod_df["startedAt"] = pd.to_datetime(pod_df["startedAt"], errors="coerce", utc=True)
pod_df = pod_df.dropna(subset=["createdAt", "startedAt"])

# Vérification
print(pod_df.dtypes[["createdAt", "startedAt"]])

pod_df["duration_ms"] = (pod_df["startedAt"] - pod_df["createdAt"]).dt.total_seconds() * 1000
# Vérifier le résultat
print(pod_df[["pod", "container_name", "duration_ms"]].head())
pod_df.to_csv("pod_df_200ms_1core.csv", index=False)
# Out:
# createdAt    datetime64[ns, UTC]
# startedAt    datetime64[ns, UTC]
# dtype: object
#                                            pod container_name  duration_ms
# 0  grayscale-00001-deployment-5875667469-j8q54    queue-proxy    96.551792
# 1    graphgen-00001-deployment-f5bfdc858-wsrp6    queue-proxy    85.144181
# 2      resnet-00001-deployment-5ccbb786c-tgtp5    queue-proxy    95.142156
# 3   pagerank-00001-deployment-669c956d7d-gc6hg    queue-proxy    95.960207
# 4    linpack-00001-deployment-59cb5bb6f4-vkqks    queue-proxy   100.451017

# %%
all_data.to_csv("all_data_200ms_1core.csv", index=False)
acti_df.to_csv("acti_df_200ms_1core.csv", index=False)
auto_df.to_csv("auto_df_200ms_1core.csv", index=False)
kourier_df.to_csv("kourier_df_200ms_1core.csv", index=False)
