# %%
ls
# Out:
# acti_df_50ms_hybrid.csv         invocation_results_fixed6.csv
# activator_20260423_130558.log   invocation_results_fixed7.csv
# activator_20260423_131203.log   invocation_results_fixed8.csv
# activator_20260423_131834.log   invocation_results_fixed9.csv
# activator_20260423_132613.log   kourier10.txt
# activator_20260423_133236.log   kourier1.txt
# activator_20260423_133819.log   kourier2.txt
# activator_20260423_134538.log   kourier3.txt
# activator_20260423_135320.log   kourier4.txt
# activator_20260423_140016.log   kourier5.txt
# activator_20260423_140655.log   kourier6.txt
# all_data_50ms_hybrid.csv        kourier7.txt
# auto_df_50ms_hybrid.csv         kourier8.txt
# autoscaler_20260423_130558.log  kourier9.txt
# autoscaler_20260423_131203.log  kourier.csv
# autoscaler_20260423_131834.log  kourier_df_50ms_hybrid.csv
# autoscaler_20260423_132613.log  logs/
# autoscaler_20260423_133236.log  pod_df_50ms_hybrid.csv
# autoscaler_20260423_133819.log  reconcile_times1.csv
# autoscaler_20260423_134538.log  reconcile_times2.csv
# autoscaler_20260423_135320.log  scheduler_20260423_130558.log
# autoscaler_20260423_140016.log  scheduler_20260423_131203.log
# autoscaler_20260423_140655.log  scheduler_20260423_131834.log
# context_handler_times1.csv      scheduler_20260423_132613.log
# context_handler_times2.csv      scheduler_20260423_133236.log
# context_handler_times3.csv      scheduler_20260423_133819.log
# context_handler_times4.csv      scheduler_20260423_134538.log
# context_handler_times5.csv      scheduler_20260423_135320.log
# context_handler_times6.csv      scheduler_20260423_140016.log
# context_handler_times7.csv      scheduler_20260423_140655.log
# invocation_results_fixed10.csv  scheduler_times.csv
# invocation_results_fixed1.csv   script_activator.py
# invocation_results_fixed2.csv   script_autoscale.py
# invocation_results_fixed3.csv   script_kourier.py
# invocation_results_fixed4.csv   script_scheduler.py
# invocation_results_fixed5.csv   Untitled3.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_results_fixed1.csv",
    "invocation_results_fixed2.csv",
    "invocation_results_fixed3.csv",
    "invocation_results_fixed4.csv",
    "invocation_results_fixed5.csv",
    "invocation_results_fixed6.csv",
    "invocation_results_fixed7.csv",
    "invocation_results_fixed8.csv",
    "invocation_results_fixed9.csv",
    "invocation_results_fixed10.csv"
]
kourier = [
   "kourier.csv"
]

pods = [
    "logs/containers_live_20260423_130556.csv",
    "logs/containers_live_20260423_131201.csv",
    "logs/containers_live_20260423_131830.csv",
    "logs/containers_live_20260423_132608.csv",
    "logs/containers_live_20260423_133233.csv",
    "logs/containers_live_20260423_133758.csv",
    "logs/containers_live_20260423_134534.csv",
    "logs/containers_live_20260423_135316.csv",
    "logs/containers_live_20260423_140013.csv",
    "logs/containers_live_20260423_140651.csv"
  
   
]

auto = [
    
    "reconcile_times1.csv",
    "reconcile_times2.csv"
    
   
    
]

acti = [
    "context_handler_times1.csv",
    "context_handler_times2.csv",
    "context_handler_times3.csv",
    "context_handler_times4.csv",
    "context_handler_times5.csv",
    "context_handler_times6.csv",
    "context_handler_times7.csv",
   
    
]
scheduler = pd.read_csv('scheduler_times.csv')

# concaténation

#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

#kourier
kourier_dfs = [pd.read_csv(f) for f in kourier]
kourier_df = pd.concat(kourier_dfs, ignore_index=True)

#pod queue-proxy
dfs = [pd.read_csv(f) for f in pods]  
pod_df = pd.concat(dfs, ignore_index=True)  

#autoscaler
dfs = [pd.read_csv(f) for f in auto]  
auto_df = pd.concat(dfs, ignore_index=True)  

#activator
dfs = [pd.read_csv(f) for f in acti]  
acti_df = pd.concat(dfs, ignore_index=True)  

#acti = pd.read_csv('context_handler_times1.csv')
#auto = pd.read_csv('reconcile_times1.csv')
#df_percentil = pd.read_csv('latency_percentiles.csv')

# %%
#conversion en ms

all_data['execution_time_sec'] = all_data['execution_time_sec'] * 1000


pod_df["createdAt"] = pd.to_datetime(pod_df["createdAt"], errors="coerce", utc=True)
pod_df["startedAt"] = pd.to_datetime(pod_df["startedAt"], errors="coerce", utc=True)
pod_df = pod_df.dropna(subset=["createdAt", "startedAt"])

# Vérification
print(pod_df.dtypes[["createdAt", "startedAt"]])

pod_df["duration_ms"] = (pod_df["startedAt"] - pod_df["createdAt"]).dt.total_seconds() * 1000
# Vérifier le résultat
print(pod_df[["pod", "container_name", "duration_ms"]].head())
pod_df.to_csv("pod_df_50ms_hybrid.csv", index=False)
# Out:
# createdAt    datetime64[ns, UTC]
# startedAt    datetime64[ns, UTC]
# dtype: object
#                                                  pod container_name  \
# 0          linpack-00001-deployment-5786f975fd-btxrl    queue-proxy
# 1          fetchdata-00001-deployment-6f7fd5c6-x5ldv    queue-proxy
# 2         pagerank-00001-deployment-5868dc586f-97k22    queue-proxy
# 3  fastfouriertransform-00001-deployment-657cc65f...    queue-proxy
# 4        genmatrix-00001-deployment-5df4b84798-4zknq    queue-proxy
#
#    duration_ms
# 0   119.789441
# 1    98.767987
# 2    96.261838
# 3    95.062057
# 4    94.732948

# %%
all_data.to_csv("all_data_50ms_hybrid.csv", index=False)
acti_df.to_csv("acti_df_50ms_hybrid.csv", index=False)
auto_df.to_csv("auto_df_50ms_hybrid.csv", index=False)
kourier_df.to_csv("kourier_df_50ms_hybrid.csv", index=False)
