# %%
ls
# Out:
# activator_20260622_130811.log   invocation_decomposed9.csv
# activator_20260622_131904.log   kourier10.txt
# activator_20260622_132808.log   kourier1.txt
# activator_20260622_134226.log   kourier2.txt
# activator_20260622_134917.log   kourier3.txt
# activator_20260622_135731.log   kourier4.txt
# activator_20260622_140910.log   kourier6.txt
# activator_20260622_141959.log   kourier7.txt
# activator_20260622_142956.log   kourier8.txt
# all_data_decomposed_100ms.csv   kourier9.txt
# antela_data.csv                 power_100ms.csv
# autoscaler_20260622_130811.log  scheduler_20260622_130811.log
# autoscaler_20260622_131904.log  scheduler_20260622_131904.log
# autoscaler_20260622_132808.log  scheduler_20260622_132808.log
# autoscaler_20260622_134226.log  scheduler_20260622_134226.log
# autoscaler_20260622_134917.log  scheduler_20260622_134917.log
# autoscaler_20260622_135731.log  scheduler_20260622_135731.log
# autoscaler_20260622_140910.log  scheduler_20260622_140910.log
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
    "invocation_decomposed4.csv",
    #"invocation_decomposed5.csv",
    "invocation_decomposed6.csv",
    "invocation_decomposed7.csv",
    "invocation_decomposed8.csv",
    "invocation_decomposed9.csv",
    "invocation_decomposed10.csv"
]


#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

power = [
     "antela_data.csv",
    # "antela_data1.csv",
     
]

dfs = [pd.read_csv(f) for f in power]
power_df = pd.concat(dfs, ignore_index=True)

# %%
all_data.to_csv("all_data_decomposed_100ms.csv", index=False)

# %%
power_df.to_csv("power_100ms.csv", index=False)
