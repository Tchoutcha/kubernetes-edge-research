# %%
ls
# Out:
# activator_20260622_111034.log   invocation_decomposed9.csv
# activator_20260622_111944.log   kourier10.txt
# activator_20260622_112715.log   kourier1.txt
# activator_20260622_113939.log   kourier2.txt
# activator_20260622_114806.log   kourier3.txt
# activator_20260622_115829.log   kourier4.txt
# activator_20260622_121038.log   kourier5.txt
# activator_20260622_121736.log   kourier6.txt
# activator_20260622_123831.log   kourier7.txt
# all_data_decomposed_50ms.csv    kourier8.txt
# antela_data.csv                 kourier9.txt
# autoscaler_20260622_111034.log  logs/
# autoscaler_20260622_111944.log  power_50ms.csv
# autoscaler_20260622_112715.log  scheduler_20260622_111034.log
# autoscaler_20260622_113939.log  scheduler_20260622_111944.log
# autoscaler_20260622_114806.log  scheduler_20260622_112715.log
# autoscaler_20260622_115829.log  scheduler_20260622_113939.log
# autoscaler_20260622_121038.log  scheduler_20260622_114806.log
# autoscaler_20260622_121736.log  scheduler_20260622_115829.log
# autoscaler_20260622_123831.log  scheduler_20260622_121038.log
# invocation_decomposed10.csv     scheduler_20260622_121736.log
# invocation_decomposed1.csv      scheduler_20260622_123831.log
# invocation_decomposed2.csv      Untitled.ipynb
# invocation_decomposed3.csv      workload_100ms.csv
# invocation_decomposed4.csv      workload_10ms.csv
# invocation_decomposed5.csv      workload_10s.csv
# invocation_decomposed6.csv      workload_1s.csv
# invocation_decomposed7.csv      workload_200ms.csv
# invocation_decomposed8.csv      workload_50ms.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
    "invocation_decomposed4.csv",
    "invocation_decomposed5.csv",
    "invocation_decomposed6.csv",
    "invocation_decomposed7.csv",
    "invocation_decomposed8.csv",
    "invocation_decomposed9.csv",
    "invocation_decomposed10.csv"
]


#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

power = [
     "antela_data.csv",
    # "antela_data1.csv",
     
]

dfs = [pd.read_csv(f) for f in power]
power_df = pd.concat(dfs, ignore_index=True)

# %%
all_data.to_csv("all_data_decomposed_50ms.csv", index=False)

# %%
power_df.to_csv("power_50ms.csv", index=False)
