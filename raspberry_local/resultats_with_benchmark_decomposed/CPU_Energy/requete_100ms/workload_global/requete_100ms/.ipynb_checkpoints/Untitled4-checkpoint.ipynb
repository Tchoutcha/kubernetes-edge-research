# %%
ls
# Out:
# activator_20260506_124337.log        kourier5.txt
# activator_20260506_125655.log        kourier6.txt
# activator_20260506_130644.log        kourier7.txt
# activator_20260506_131421.log        kourier8.txt
# activator_20260506_132216.log        kourier9.txt
# activator_20260506_133412.log        kourier.csv
# activator_20260506_134315.log        kourier_decomposed_df_100ms_1core.csv
# activator_20260506_140336.log        logs/
# activator_20260506_141228.log        output10.txt
# all_data_decomposed_100ms_1core.csv  output1.txt
# autoscaler_20260506_124337.log       output2.txt
# autoscaler_20260506_125655.log       output3.txt
# autoscaler_20260506_130644.log       output4.txt
# autoscaler_20260506_131421.log       output5.txt
# autoscaler_20260506_132216.log       output6.txt
# autoscaler_20260506_133412.log       output7.txt
# autoscaler_20260506_134315.log       output8.txt
# autoscaler_20260506_140336.log       output9.txt
# autoscaler_20260506_141228.log       pod_decomposed_df_100ms_1core.csv
# invocation_decomposed10.csv          scheduler_20260506_124337.log
# invocation_decomposed1.csv           scheduler_20260506_125655.log
# invocation_decomposed2.csv           scheduler_20260506_130644.log
# invocation_decomposed3.csv           scheduler_20260506_131421.log
# invocation_decomposed4.csv           scheduler_20260506_132216.log
# invocation_decomposed5.csv           scheduler_20260506_133412.log
# invocation_decomposed6.csv           scheduler_20260506_134315.log
# invocation_decomposed7.csv           scheduler_20260506_140336.log
# invocation_decomposed8.csv           scheduler_20260506_141228.log
# invocation_decomposed9.csv           scheduler_times.csv
# kourier10.txt                        script_activator.py
# kourier1.txt                         script_autoscale.py
# kourier2.txt                         script_kourier.py
# kourier3.txt                         script_scheduler.py
# kourier4.txt                         Untitled4.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
    "invocation_decomposed4.csv",
    "invocation_decomposed5.csv",
    "invocation_decomposed6.csv",
    "invocation_decomposed7.csv",
    "invocation_decomposed8.csv",
    "invocation_decomposed9.csv",
    "invocation_decomposed10.csv"
]
kourier = [
   "kourier.csv"
]

pods = [
    "logs/containers_live_20260506_124327.csv",
    "logs/containers_live_20260506_125652.csv",
    "logs/containers_live_20260506_130642.csv",
    "logs/containers_live_20260506_131418.csv",
    "logs/containers_live_20260506_132213.csv",
    "logs/containers_live_20260506_133405.csv",
    "logs/containers_live_20260506_134313.csv",
    "logs/containers_live_20260506_135409.csv",
    "logs/containers_live_20260506_140333.csv",
    "logs/containers_live_20260506_141226.csv"
  
   
] 

#auto = [
    
   # "reconcile_times1.csv",
    #"reconcile_times2.csv",
    #"reconcile_times3.csv"
   
    
#]

#acti = [
  #  "context_handler_times1.csv",
  #  "context_handler_times2.csv",
  #  "context_handler_times3.csv",
   # "context_handler_times4.csv",
   # "context_handler_times5.csv",
   # "context_handler_times6.csv",
   # "context_handler_times7.csv",
   
    
#]
scheduler = pd.read_csv('scheduler_times.csv')

# concaténation

#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

#kourier
kourier_dfs = [pd.read_csv(f) for f in kourier]
kourier_df = pd.concat(kourier_dfs, ignore_index=True)

#pod queue-proxy
dfs = [pd.read_csv(f) for f in pods]  
pod_df = pd.concat(dfs, ignore_index=True)  

#autoscaler
#dfs = [pd.read_csv(f) for f in auto]  
#auto_df = pd.concat(dfs, ignore_index=True)  

#activator
#dfs = [pd.read_csv(f) for f in acti]  
#acti_df = pd.concat(dfs, ignore_index=True)  

#acti = pd.read_csv('context_handler_times1.csv')
#auto = pd.read_csv('reconcile_times1.csv')
#df_percentil = pd.read_csv('latency_percentiles.csv')

# %%
pod_df["createdAt"] = pd.to_datetime(pod_df["createdAt"], errors="coerce", utc=True)
pod_df["startedAt"] = pd.to_datetime(pod_df["startedAt"], errors="coerce", utc=True)
pod_df = pod_df.dropna(subset=["createdAt", "startedAt"])

# Vérification
print(pod_df.dtypes[["createdAt", "startedAt"]])

pod_df["duration_ms"] = (pod_df["startedAt"] - pod_df["createdAt"]).dt.total_seconds() * 1000
# Vérifier le résultat
print(pod_df[["pod", "container_name", "duration_ms"]].head())
pod_df.to_csv("pod_decomposed_df_100ms_1core.csv", index=False)
# Out:
# createdAt    datetime64[ns, UTC]
# startedAt    datetime64[ns, UTC]
# dtype: object
#                                                  pod container_name  \
# 0         grayscale-00001-deployment-94d4646fd-rc2gq    queue-proxy
# 1         fetchdata-00001-deployment-99f85775b-8dt5p    queue-proxy
# 2          linpack-00001-deployment-5f6694d7c6-p7rnr    queue-proxy
# 3  fastfouriertransform-00001-deployment-5f7f4bb8...    queue-proxy
# 4        mobilenet-00001-deployment-59bbf999b6-mps48    queue-proxy
#
#    duration_ms
# 0   168.218585
# 1   137.649634
# 2   117.783726
# 3   100.941942
# 4   134.120224

# %%
all_data.to_csv("all_data_decomposed_100ms_1core.csv", index=False)
#acti_df.to_csv("acti_df_10ms_1core.csv", index=False)
#auto_df.to_csv("auto_df_10ms_1core.csv", index=False)
kourier_df.to_csv("kourier_decomposed_df_100ms_1core.csv", index=False)
