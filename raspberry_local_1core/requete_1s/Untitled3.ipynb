# %%
ls
# Out:
# acti_df_1s_1core.csv            kourier10.txt
# activator_20260417_095258.log   kourier1.txt
# activator_20260417_103424.log   kourier2.txt
# activator_20260417_111849.log   kourier3.txt
# activator_20260417_120419.log   kourier4.txt
# activator_20260417_124326.log   kourier5.txt
# activator_20260417_135737.log   kourier6.txt
# activator_20260417_144108.log   kourier7.txt
# activator_20260417_151836.log   kourier8.txt
# activator_20260417_155928.log   kourier9.txt
# activator_20260417_163959.log   kourier.csv
# all_data_1s_1core.csv           kourier_df_1s_1core.csv
# auto_df_1s_1core.csv            logs/
# autoscaler_20260417_095258.log  pod_df_1s_1core.csv
# autoscaler_20260417_103424.log  reconcile_times10.csv
# autoscaler_20260417_111849.log  reconcile_times1.csv
# autoscaler_20260417_120419.log  reconcile_times2.csv
# autoscaler_20260417_124326.log  reconcile_times3.csv
# autoscaler_20260417_135737.log  reconcile_times4.csv
# autoscaler_20260417_144108.log  reconcile_times5.csv
# autoscaler_20260417_151836.log  reconcile_times6.csv
# autoscaler_20260417_155928.log  reconcile_times7.csv
# autoscaler_20260417_163959.log  reconcile_times8.csv
# context_handler_times1.csv      reconcile_times9.csv
# context_handler_times2.csv      scheduler_20260417_095258.log
# context_handler_times3.csv      scheduler_20260417_103424.log
# context_handler_times4.csv      scheduler_20260417_111849.log
# context_handler_times5.csv      scheduler_20260417_120419.log
# context_handler_times6.csv      scheduler_20260417_124326.log
# context_handler_times7.csv      scheduler_20260417_135737.log
# invocation_results_fixed10.csv  scheduler_20260417_144108.log
# invocation_results_fixed1.csv   scheduler_20260417_151836.log
# invocation_results_fixed2.csv   scheduler_20260417_155928.log
# invocation_results_fixed3.csv   scheduler_20260417_163959.log
# invocation_results_fixed4.csv   scheduler_times.csv
# invocation_results_fixed5.csv   script_activator.py
# invocation_results_fixed6.csv   script_autoscale.py
# invocation_results_fixed7.csv   script_kourier.py
# invocation_results_fixed8.csv   script_scheduler.py
# invocation_results_fixed9.csv   Untitled3.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_results_fixed1.csv",
    "invocation_results_fixed2.csv",
    "invocation_results_fixed3.csv",
    "invocation_results_fixed4.csv",
    "invocation_results_fixed5.csv",
    "invocation_results_fixed6.csv",
    "invocation_results_fixed7.csv",
    "invocation_results_fixed8.csv",
    "invocation_results_fixed9.csv",
    "invocation_results_fixed10.csv"
]
kourier = [
   "kourier.csv"
]

pods = [
    "logs/containers_live_20260417_095244.csv",
    "logs/containers_live_20260417_103419.csv",
    "logs/containers_live_20260417_111845.csv",
    "logs/containers_live_20260417_120415.csv",
    "logs/containers_live_20260417_124321.csv",
    "logs/containers_live_20260417_135732.csv",
    "logs/containers_live_20260417_144102.csv",
    "logs/containers_live_20260417_151833.csv",
    "logs/containers_live_20260417_155924.csv",
    "logs/containers_live_20260417_163955.csv"
  
   
]

auto = [
    
    "reconcile_times1.csv",
    "reconcile_times2.csv",
    "reconcile_times3.csv",
    "reconcile_times4.csv",
    "reconcile_times5.csv",
    "reconcile_times6.csv",
    "reconcile_times7.csv",
    "reconcile_times8.csv",
    "reconcile_times9.csv",
    "reconcile_times10.csv"
   
    
]

acti = [
    "context_handler_times1.csv",
    "context_handler_times2.csv",
    "context_handler_times3.csv",
    "context_handler_times4.csv",
    "context_handler_times5.csv",
    "context_handler_times6.csv",
    "context_handler_times7.csv",
   
    
]
scheduler = pd.read_csv('scheduler_times.csv')

# concaténation

#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

#kourier
kourier_dfs = [pd.read_csv(f) for f in kourier]
kourier_df = pd.concat(kourier_dfs, ignore_index=True)

#pod queue-proxy
dfs = [pd.read_csv(f) for f in pods]  
pod_df = pd.concat(dfs, ignore_index=True)  

#autoscaler
dfs = [pd.read_csv(f) for f in auto]  
auto_df = pd.concat(dfs, ignore_index=True)  

#activator
dfs = [pd.read_csv(f) for f in acti]  
acti_df = pd.concat(dfs, ignore_index=True)  

#acti = pd.read_csv('context_handler_times1.csv')
#auto = pd.read_csv('reconcile_times1.csv')
#df_percentil = pd.read_csv('latency_percentiles.csv')

# %%
#conversion en ms

all_data['execution_time_sec'] = all_data['execution_time_sec'] * 1000


pod_df["createdAt"] = pd.to_datetime(pod_df["createdAt"], errors="coerce", utc=True)
pod_df["startedAt"] = pd.to_datetime(pod_df["startedAt"], errors="coerce", utc=True)
pod_df = pod_df.dropna(subset=["createdAt", "startedAt"])

# Vérification
print(pod_df.dtypes[["createdAt", "startedAt"]])

pod_df["duration_ms"] = (pod_df["startedAt"] - pod_df["createdAt"]).dt.total_seconds() * 1000
# Vérifier le résultat
print(pod_df[["pod", "container_name", "duration_ms"]].head())
pod_df.to_csv("pod_df_1s_1core.csv", index=False)
# Out:
# createdAt    datetime64[ns, UTC]
# startedAt    datetime64[ns, UTC]
# dtype: object
#                                                  pod container_name  \
# 0        genmatrix-00001-deployment-57fdd67855-dz6sn    queue-proxy
# 1        grayscale-00001-deployment-5875667469-l2n4s    queue-proxy
# 2  fastfouriertransform-00001-deployment-7f6c4dd4...    queue-proxy
# 3            resnet-00001-deployment-5ccbb786c-gl8kc    queue-proxy
# 4         pagerank-00001-deployment-669c956d7d-gggpj    queue-proxy
#
#    duration_ms
# 0    95.454352
# 1    97.017736
# 2    94.560800
# 3   100.429685
# 4    89.546260

# %%
all_data.to_csv("all_data_1s_1core.csv", index=False)
acti_df.to_csv("acti_df_1s_1core.csv", index=False)
auto_df.to_csv("auto_df_1s_1core.csv", index=False)
kourier_df.to_csv("kourier_df_1s_1core.csv", index=False)
