# %%
ls
# Out:
# activator_20260427_140724.log       kourier4.txt
# activator_20260427_141457.log       kourier5.txt
# activator_20260427_142210.log       kourier6.txt
# activator_20260427_142735.log       kourier7.txt
# activator_20260427_143620.log       kourier8.txt
# activator_20260427_144516.log       kourier9.txt
# activator_20260427_145241.log       kourier.csv
# activator_20260427_150008.log       kourier_df_10ms_apiserver_pinned.csv
# activator_20260427_151000.log       latency_percentiles10.csv
# activator_20260427_151902.log       latency_percentiles2.csv
# all_data_10ms_apiserver_pinned.csv  latency_percentiles3.csv
# autoscaler_20260427_140724.log      latency_percentiles4.csv
# autoscaler_20260427_141457.log      latency_percentiles5.csv
# autoscaler_20260427_142210.log      latency_percentiles6.csv
# autoscaler_20260427_142735.log      latency_percentiles7.csv
# autoscaler_20260427_143620.log      latency_percentiles8.csv
# autoscaler_20260427_144516.log      latency_percentiles9.csv
# autoscaler_20260427_145241.log      logs/
# autoscaler_20260427_150008.log      scheduler_20260427_140724.log
# autoscaler_20260427_151000.log      scheduler_20260427_141457.log
# autoscaler_20260427_151902.log      scheduler_20260427_142210.log
# invocation_results_fixed10.csv      scheduler_20260427_142735.log
# invocation_results_fixed1.csv       scheduler_20260427_143620.log
# invocation_results_fixed2.csv       scheduler_20260427_144516.log
# invocation_results_fixed3.csv       scheduler_20260427_145241.log
# invocation_results_fixed4.csv       scheduler_20260427_150008.log
# invocation_results_fixed5.csv       scheduler_20260427_151000.log
# invocation_results_fixed6.csv       scheduler_20260427_151902.log
# invocation_results_fixed7.csv       scheduler_times-10ms_apiserver_pinned.csv
# invocation_results_fixed8.csv       script_activator.py
# invocation_results_fixed9.csv       script_autoscale.py
# kourier10.txt                       script_kourier.py
# kourier1.txt                        script_scheduler.py
# kourier2.txt                        Untitled3.ipynb
# kourier3.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_results_fixed1.csv",
    "invocation_results_fixed2.csv",
    "invocation_results_fixed3.csv",
    "invocation_results_fixed4.csv",
    "invocation_results_fixed5.csv",
    "invocation_results_fixed6.csv",
    "invocation_results_fixed7.csv",
    "invocation_results_fixed8.csv",
    "invocation_results_fixed9.csv",
    "invocation_results_fixed10.csv"
]
kourier = [
   "kourier.csv"
]

pods = [
    "logs/containers_live_20260427_140421.csv",
    "logs/containers_live_20260427_141453.csv",
    "logs/containers_live_20260427_142206.csv",
    "logs/containers_live_20260427_142724.csv",
    "logs/containers_live_20260427_143616.csv",
    "logs/containers_live_20260427_144512.csv",
    "logs/containers_live_20260427_145237.csv",
    "logs/containers_live_20260427_150005.csv",
    "logs/containers_live_20260427_150948.csv",
    "logs/containers_live_20260427_151852.csv"
  
   
]



scheduler = pd.read_csv('scheduler_times.csv')

# concaténation

#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

#kourier
kourier_dfs = [pd.read_csv(f) for f in kourier]
kourier_df = pd.concat(kourier_dfs, ignore_index=True)

#pod queue-proxy
dfs = [pd.read_csv(f) for f in pods]  
pod_df = pd.concat(dfs, ignore_index=True)  

#autoscaler
#dfs = [pd.read_csv(f) for f in auto]  
#auto_df = pd.concat(dfs, ignore_index=True)  

#activator
#dfs = [pd.read_csv(f) for f in acti]  
#acti_df = pd.concat(dfs, ignore_index=True)  

#acti = pd.read_csv('context_handler_times1.csv')
#auto = pd.read_csv('reconcile_times1.csv')
#df_percentil = pd.read_csv('latency_percentiles.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 34
#      13 kourier = [
#      14    "kourier.csv"
#      15 ]
#      17 pods = [
#      18     "logs/containers_live_20260427_140421.csv",
#      19     "logs/containers_live_20260427_141453.csv",
#    (...)     29
#      30 ]
# ---> 34 scheduler = pd.read_csv('scheduler_times.csv')
#      36 # concaténation
#      37
#      38 #invocation
#      39 dfs = [pd.read_csv(f) for f in files]
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'scheduler_times.csv'

# %%
#conversion en ms

all_data['execution_time_sec'] = all_data['execution_time_sec'] * 1000


pod_df["createdAt"] = pd.to_datetime(pod_df["createdAt"], errors="coerce", utc=True)
pod_df["startedAt"] = pd.to_datetime(pod_df["startedAt"], errors="coerce", utc=True)
pod_df = pod_df.dropna(subset=["createdAt", "startedAt"])

# Vérification
print(pod_df.dtypes[["createdAt", "startedAt"]])

pod_df["duration_ms"] = (pod_df["startedAt"] - pod_df["createdAt"]).dt.total_seconds() * 1000
# Vérifier le résultat
print(pod_df[["pod", "container_name", "duration_ms"]].head())
pod_df.to_csv("pod_df_10ms_apiserver_pinned.csv", index=False)

# %%
all_data.to_csv("all_data_10ms_apiserver_pinned.csv", index=False)
#acti_df.to_csv("acti_df_10ms_1core.csv", index=False)
#auto_df.to_csv("auto_df_10ms_1core.csv", index=False)
kourier_df.to_csv("kourier_df_10ms_apiserver_pinned.csv", index=False)
