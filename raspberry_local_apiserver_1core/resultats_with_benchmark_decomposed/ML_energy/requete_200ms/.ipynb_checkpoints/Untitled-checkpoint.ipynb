# %%
ls
# Out:
# activator_20260702_141113.log   kourier10.txt
# activator_20260702_142236.log   kourier1.csv
# activator_20260702_143402.log   kourier2.txt
# activator_20260702_144500.log   kourier4.txt
# activator_20260702_145609.log   kourier5.txt
# activator_20260702_150819.log   kourier6.txt
# activator_20260702_151927.log   kourier7.txt
# activator_20260702_153924.log   kourier8.txt
# activator_20260702_155351.log   logs/
# activator_20260702_160620.log   scheduler_20260702_141113.log
# antela_data.csv                 scheduler_20260702_142236.log
# autoscaler_20260702_141113.log  scheduler_20260702_143402.log
# autoscaler_20260702_142236.log  scheduler_20260702_144500.log
# autoscaler_20260702_143402.log  scheduler_20260702_145609.log
# autoscaler_20260702_144500.log  scheduler_20260702_150819.log
# autoscaler_20260702_145609.log  scheduler_20260702_151927.log
# autoscaler_20260702_150819.log  scheduler_20260702_153924.log
# autoscaler_20260702_151927.log  scheduler_20260702_155351.log
# autoscaler_20260702_153924.log  scheduler_20260702_160620.log
# autoscaler_20260702_155351.log  scheduler_times.csv
# autoscaler_20260702_160620.log  script_activator.py
# invocation_decomposed10.csv     script_autoscale.py
# invocation_decomposed1.csv      script_kourier.py
# invocation_decomposed2.csv      script_scheduler.py
# invocation_decomposed3.csv      Untitled.ipynb
# invocation_decomposed4.csv      workload_100ms.csv
# invocation_decomposed5.csv      workload_10ms.csv
# invocation_decomposed6.csv      workload_1s.csv
# invocation_decomposed7.csv      workload_200ms.csv
# invocation_decomposed8.csv      workload_50ms.csv
# invocation_decomposed9.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
    "invocation_decomposed4.csv",
    "invocation_decomposed5.csv",
    "invocation_decomposed6.csv",
    "invocation_decomposed7.csv",
    "invocation_decomposed8.csv",
    "invocation_decomposed9.csv",
    "invocation_decomposed10.csv"
]


#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

power = [
     "antela_data.csv",
     #"antela_data1.csv"
]

dfs = [pd.read_csv(f) for f in power]
power_df = pd.concat(dfs, ignore_index=True)

# %%
all_data.to_csv("all_data_decomposed_200ms_apiserver.csv", index=False)
power_df.to_csv("power_200ms_apiserver.csv", index=False)
