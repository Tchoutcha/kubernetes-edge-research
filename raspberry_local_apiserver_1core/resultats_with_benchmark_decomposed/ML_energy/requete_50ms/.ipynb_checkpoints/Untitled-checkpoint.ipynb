# %%
ls
# Out:
# activator_20260702_104107.log           kourier1.csv
# activator_20260702_105017.log           kourier1.txt
# activator_20260702_105958.log           kourier2.txt
# activator_20260702_111220.log           kourier3.txt
# activator_20260702_112013.log           kourier4.txt
# activator_20260702_113015.log           kourier5.txt
# activator_20260702_115218.log           kourier6.txt
# activator_20260702_120107.log           kourier7.txt
# activator_20260702_121015.log           kourier8.txt
# activator_20260702_122000.log           kourier9.txt
# activator_20260702_122111.log           kourier.txt
# all_data_decomposed_50ms_apiserver.csv  logs/
# antela_data.csv                         scheduler_20260702_104107.log
# autoscaler_20260702_104107.log          scheduler_20260702_105017.log
# autoscaler_20260702_105017.log          scheduler_20260702_105958.log
# autoscaler_20260702_105958.log          scheduler_20260702_111220.log
# autoscaler_20260702_111220.log          scheduler_20260702_112013.log
# autoscaler_20260702_112013.log          scheduler_20260702_113015.log
# autoscaler_20260702_113015.log          scheduler_20260702_115218.log
# autoscaler_20260702_115218.log          scheduler_20260702_120107.log
# autoscaler_20260702_120107.log          scheduler_20260702_121015.log
# autoscaler_20260702_121015.log          scheduler_20260702_122000.log
# autoscaler_20260702_122000.log          scheduler_20260702_122111.log
# autoscaler_20260702_122111.log          scheduler_times.csv
# invocation_decomposed10.csv             script_activator.py
# invocation_decomposed1.csv              script_autoscale.py
# invocation_decomposed2.csv              script_kourier.py
# invocation_decomposed3.csv              script_scheduler.py
# invocation_decomposed4.csv              Untitled.ipynb
# invocation_decomposed5.csv              workload_100ms.csv
# invocation_decomposed6.csv              workload_10ms.csv
# invocation_decomposed7.csv              workload_1s.csv
# invocation_decomposed8.csv              workload_200ms.csv
# invocation_decomposed9.csv              workload_50ms.csv
# kourier10.txt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
files = [
    "invocation_decomposed1.csv",
    "invocation_decomposed2.csv",
    "invocation_decomposed3.csv",
    "invocation_decomposed4.csv",
    "invocation_decomposed5.csv",
    "invocation_decomposed6.csv",
    "invocation_decomposed7.csv",
    "invocation_decomposed8.csv",
    "invocation_decomposed9.csv",
    "invocation_decomposed10.csv"
]


#invocation
dfs = [pd.read_csv(f) for f in files]
all_data = pd.concat(dfs, ignore_index=True)

power = [
     "antela_data.csv",
     #"antela_data1.csv"
]

dfs = [pd.read_csv(f) for f in power]
power_df = pd.concat(dfs, ignore_index=True)

# %%
all_data.to_csv("all_data_decomposed_50ms_apiserver.csv", index=False)
power_df.to_csv("power_50ms_apiserver.csv", index=False)
